# %%
import pandas as pd
import numpy as np

# %%
#import data and prepare
model = pd.read_csv('C:/Users/user/Documents/severity/cleaned.csv')
model.head(5)
# Out:
#   Age_band_of_driver Sex_of_driver   Educational_level  \
# 0              18-30          Male   Above high school
# 1              31-50          Male  Junior high school
# 2              18-30          Male  Junior high school
# 3              18-30          Male  Junior high school
# 4              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience   Lanes_or_Medians  \
# 0                Employee              1-2yr            Unknown
# 1                Employee         Above 10yr  Undivided Two way
# 2                Employee              1-2yr              other
# 3                Employee             5-10yr              other
# 4                Employee              2-5yr              other
#
#   Types_of_Junction Road_surface_type       Light_conditions  \
# 0       No junction     Asphalt roads               Daylight
# 1       No junction     Asphalt roads               Daylight
# ...

# %%
model['Age_band_of_driver'] = model['Age_band_of_driver'].astype('category')
model['Age_band_of_driver'] = model['Age_band_of_driver'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation Driving_experience  \
# 0                            0              1-2yr
# 1                            0         Above 10yr
# 2                            0              1-2yr
# ...

# %%
model['Sex_of_driver'] = model['Sex_of_driver'].astype('category')
model['Sex_of_driver'] = model['Sex_of_driver'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation Driving_experience  \
# 0                            0              1-2yr
# 1                            0         Above 10yr
# 2                            0              1-2yr
# ...

# %%
model['Educational_level'] = model['Educational_level'].astype('category')
model['Educational_level'] =model['Educational_level'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation Driving_experience  \
# 0                            0              1-2yr
# 1                            0         Above 10yr
# 2                            0              1-2yr
# ...

# %%
model['Vehicle_driver_relation'] = model['Vehicle_driver_relation'].astype('category')
model['Vehicle_driver_relation'] = model['Vehicle_driver_relation'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation Driving_experience  \
# 0                            0              1-2yr
# 1                            0         Above 10yr
# 2                            0              1-2yr
# ...

# %%
model['Driving_experience'] = model['Driving_experience'].astype('category')
model['Driving_experience'] =model['Driving_experience'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  \
# 0                            0                   0
# 1                            0                   3
# 2                            0                   0
# ...

# %%
model['Lanes_or_Medians'] =model['Lanes_or_Medians'].astype('category')
model['Lanes_or_Medians'] = model['Lanes_or_Medians'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Types_of_Junction'] = model['Types_of_Junction'].astype('category')
model['Types_of_Junction'] = model['Types_of_Junction'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Road_surface_type'] = model['Road_surface_type'].astype('category')
model['Road_surface_type'] = model['Road_surface_type'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Light_conditions'] = model['Light_conditions'].astype('category')
model['Light_conditions'] = model['Light_conditions'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Weather_conditions'] = model['Weather_conditions'].astype('category')
model['Weather_conditions'] = model['Weather_conditions'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Type_of_collision'] = model['Type_of_collision'].astype('category')
model['Type_of_collision'] = model['Type_of_collision'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Vehicle_movement'] = model['Vehicle_movement'].astype('category')
model['Vehicle_movement'] = model['Vehicle_movement'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Pedestrian_movement'] = model['Pedestrian_movement'].astype('category')
model['Pedestrian_movement'] = model['Pedestrian_movement'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Cause_of_accident'] = model['Cause_of_accident'].astype('category')
model['Cause_of_accident'] = model['Cause_of_accident'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model['Accident_severity'] = model['Accident_severity'].astype('category')
model['Accident_severity'] = model['Accident_severity'].cat.codes
model
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
model.isnull().sum()
# Out:
# Age_band_of_driver         0
# Sex_of_driver              0
# Educational_level          0
# Vehicle_driver_relation    0
# Driving_experience         0
# Lanes_or_Medians           0
# Types_of_Junction          0
# Road_surface_type          0
# Light_conditions           0
# Weather_conditions         0
# Type_of_collision          0
# Vehicle_movement           0
# Pedestrian_movement        0
# Cause_of_accident          0
# Accident_severity          0
# dtype: int64

# %%
#define x
x = model.drop(columns = 'Accident_severity')
x
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12311                   1              1                  5
# 12312                   4              1                  1
# 12313                   2              1                  4
# 12314                   0              0                  4
# 12315                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# ...

# %%
#define y
y = model['Accident_severity']

# %%
# split the dataset into training set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
#train the model on the training set
from sklearn.linear_model import LinearRegression
# Fit the model on the training set
LR = LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
c = LR.intercept_

# %%
c
# Out:
# 1.7310949943348657

# %%
m = LR.coef_
m
# Out:
# array([ 0.0040968 ,  0.01107327,  0.00090713, -0.00244101, -0.00235772,
#         0.00011289, -0.00071721,  0.00308984,  0.00907332,  0.00594295,
#         0.00382011, -0.00273744,  0.00777569,  0.00076424])

# %%
y_pred_train = LR.predict(x_train)

# %%
y_pred_train
# Out:
# array([1.80754542, 1.78924976, 1.85527307, ..., 1.82360063, 1.86388567,
#        1.83426174])

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train,y_pred_train)
plt.xlabel('actual Accident_severity')
plt.ylabel('Predicted Accident_severity')
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.002841864287890572

# %%
y_pred_test = LR.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred_test)
plt.xlabel('actual Accident_severity')
plt.ylabel('Predicted Accident_severity')
plt.show()

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.0009728701492074388
